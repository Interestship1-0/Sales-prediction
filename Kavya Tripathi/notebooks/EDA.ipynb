# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pwd
# Out:
# 'C:\\Users\\ASUS\\Sales_Prediction\\notebooks'

# %%
d1=pd.read_csv(r"C:\Users\ASUS\.cookiecutters\cookiecutter-data-science\Sales_Prediction\data\raw\item_categories.csv")
d1.head()
# Out:
#         item_category_name  item_category_id
# 0  PC - Гарнитуры/Наушники                 0
# 1         Аксессуары - PS2                 1
# 2         Аксессуары - PS3                 2
# 3         Аксессуары - PS4                 3
# 4         Аксессуары - PSP                 4

# %%
d1.shape
# Out:
# (84, 2)

# %%
d2=pd.read_csv(r"C:\Users\ASUS\.cookiecutters\cookiecutter-data-science\Sales_Prediction\data\raw\items.csv")
d2.head()
# Out:
#                                            item_name  item_id  \
# 0          ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0
# 1  !ABBYY FineReader 12 Professional Edition Full...        1
# 2      ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
# 3    ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3
# 4        ***КОРОБКА (СТЕКЛО)                       D        4
#
#    item_category_id
# 0                40
# 1                76
# 2                40
# 3                40
# 4                40

# %%
d2.shape
# Out:
# (22170, 3)

# %%
d3=pd.read_csv(r"C:\Users\ASUS\.cookiecutters\cookiecutter-data-science\Sales_Prediction\data\raw\sales_train.csv")
d3.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00          -1.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0

# %%
d3.shape
# Out:
# (2935849, 6)

# %%
d4=pd.read_csv(r"C:\Users\ASUS\.cookiecutters\cookiecutter-data-science\Sales_Prediction\data\raw\sample_submission.csv")
d4.head()
# Out:
#    ID  item_cnt_month
# 0   0             0.5
# 1   1             0.5
# 2   2             0.5
# 3   3             0.5
# 4   4             0.5

# %%
d4.shape
# Out:
# (214200, 2)

# %%
d5=pd.read_csv(r"C:\Users\ASUS\.cookiecutters\cookiecutter-data-science\Sales_Prediction\data\raw\shops.csv")
d5.head()
# Out:
#                         shop_name  shop_id
# 0   !Якутск Орджоникидзе, 56 фран        0
# 1   !Якутск ТЦ "Центральный" фран        1
# 2                Адыгея ТЦ "Мега"        2
# 3  Балашиха ТРК "Октябрь-Киномир"        3
# 4        Волжский ТЦ "Волга Молл"        4

# %%
d6=pd.read_csv(r"C:\Users\ASUS\.cookiecutters\cookiecutter-data-science\Sales_Prediction\data\raw\test.csv")
d6.head()
# Out:
#    ID  shop_id  item_id
# 0   0        5     5037
# 1   1        5     5320
# 2   2        5     5233
# 3   3        5     5232
# 4   4        5     5268

# %%
d6.shape
# Out:
# (214200, 3)

# %%
d5.shape
# Out:
# (60, 2)

# %%
d1.columns
# Out:
# Index(['item_category_name', 'item_category_id'], dtype='object')

# %%
d2.columns
# Out:
# Index(['item_name', 'item_id', 'item_category_id'], dtype='object')

# %%
item_category=pd.merge(d1,d2)

# %%
item_category.columns
# Out:
# Index(['item_category_name', 'item_category_id', 'item_name', 'item_id'], dtype='object')

# %%
item_category.head()
# Out:
#         item_category_name  item_category_id  \
# 0  PC - Гарнитуры/Наушники                 0
# 1  PC - Гарнитуры/Наушники                 0
# 2  PC - Гарнитуры/Наушники                 0
# 3  PC - Гарнитуры/Наушники                 0
# 4         Аксессуары - PS2                 1
#
#                                            item_name  item_id
# 0  PC: Гарнитура HyperX Cloud Core игровая стерео...     5441
# 1                        Наушники PHILIPS SBC HC8680    16255
# 2                             Наушники RITMIX RH-120    16256
# 3                       Наушники RITMIX RH-124 Black    16257
# 4  PS2: Карта памяти 8 Мб черная (Memory Card 8Mb...     5606

# %%
item_category.size
# Out:
# 88680

# %%
item_category.shape
# Out:
# (22170, 4)

# %%
item_category.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22170 entries, 0 to 22169
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   item_category_name  22170 non-null  object
#  1   item_category_id    22170 non-null  int64
#  2   item_name           22170 non-null  object
#  3   item_id             22170 non-null  int64
# dtypes: int64(2), object(2)
# memory usage: 866.0+ KB

# %%
test_final=pd.merge(pd.merge(d5,d6),pd.merge(d1,d2))

# %%
test_final.head()
# Out:
#                         shop_name  shop_id     ID  item_id item_category_name  \
# 0                Адыгея ТЦ "Мега"        2  20400     5037         Игры - PS3
# 1  Балашиха ТРК "Октябрь-Киномир"        3  15300     5037         Игры - PS3
# 2        Волжский ТЦ "Волга Молл"        4   5100     5037         Игры - PS3
# 3          Вологда ТРЦ "Мармелад"        5      0     5037         Игры - PS3
# 4      Воронеж (Плехановская, 13)        6  10200     5037         Игры - PS3
#
#    item_category_id                       item_name
# 0                19  NHL 15 [PS3, русские субтитры]
# 1                19  NHL 15 [PS3, русские субтитры]
# 2                19  NHL 15 [PS3, русские субтитры]
# 3                19  NHL 15 [PS3, русские субтитры]
# 4                19  NHL 15 [PS3, русские субтитры]

# %%
test_final.to_csv(r'C:\Users\ASUS\.cookiecutters\cookiecutter-data-science\Sales_Prediction\data\interim\test_final.csv')

# %%
test_final.shape
# Out:
# (214200, 7)

# %%
train_final=pd.merge(pd.merge(d3,d5),pd.merge(d1,d2))

# %%
train_final.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day  \
# 0  02.01.2013               0       59    22154       999.0           1.0
# 1  02.01.2013               0       25    22154       999.0           1.0
# 2  03.01.2013               0       25    22154       999.0           1.0
# 3  20.01.2013               0       25    22154       999.0           1.0
# 4  23.01.2013               0       25    22154       999.0           1.0
#
#                 shop_name item_category_name  item_category_id  \
# 0  Ярославль ТЦ "Альтаир"     Кино - Blu-Ray                37
# 1     Москва ТРК "Атриум"     Кино - Blu-Ray                37
# 2     Москва ТРК "Атриум"     Кино - Blu-Ray                37
# 3     Москва ТРК "Атриум"     Кино - Blu-Ray                37
# 4     Москва ТРК "Атриум"     Кино - Blu-Ray                37
#
#            item_name
# 0  ЯВЛЕНИЕ 2012 (BD)
# 1  ЯВЛЕНИЕ 2012 (BD)
# 2  ЯВЛЕНИЕ 2012 (BD)
# 3  ЯВЛЕНИЕ 2012 (BD)
# 4  ЯВЛЕНИЕ 2012 (BD)

# %%
train_final.shape
# Out:
# (2935849, 10)

# %%
train_final.columns
# Out:
# Index(['date', 'date_block_num', 'shop_id', 'item_id', 'item_price',
#        'item_cnt_day', 'shop_name', 'item_category_name', 'item_category_id',
#        'item_name'],
#       dtype='object')

# %%
train_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2935849 entries, 0 to 2935848
# Data columns (total 10 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   date                object
#  1   date_block_num      int64
#  2   shop_id             int64
#  3   item_id             int64
#  4   item_price          float64
#  5   item_cnt_day        float64
#  6   shop_name           object
#  7   item_category_name  object
#  8   item_category_id    int64
#  9   item_name           object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 246.4+ MB

# %%
train_final.describe()
# Out:
#        date_block_num       shop_id       item_id    item_price  item_cnt_day  \
# count    2.935849e+06  2.935849e+06  2.935849e+06  2.935849e+06  2.935849e+06
# mean     1.456991e+01  3.300173e+01  1.019723e+04  8.908532e+02  1.242641e+00
# std      9.422988e+00  1.622697e+01  6.324297e+03  1.729800e+03  2.618834e+00
# min      0.000000e+00  0.000000e+00  0.000000e+00 -1.000000e+00 -2.200000e+01
# 25%      7.000000e+00  2.200000e+01  4.476000e+03  2.490000e+02  1.000000e+00
# 50%      1.400000e+01  3.100000e+01  9.343000e+03  3.990000e+02  1.000000e+00
# 75%      2.300000e+01  4.700000e+01  1.568400e+04  9.990000e+02  1.000000e+00
# max      3.300000e+01  5.900000e+01  2.216900e+04  3.079800e+05  2.169000e+03
#
#        item_category_id
# count      2.935849e+06
# mean       4.000138e+01
# std        1.710076e+01
# min        0.000000e+00
# 25%        2.800000e+01
# 50%        4.000000e+01
# 75%        5.500000e+01
# max        8.300000e+01

# %%
train_final.item_cnt_day.value_counts()
# Out:
# 1.0      2629372
# 2.0       194201
# 3.0        47350
# 4.0        19685
# 5.0        10474
#           ...
# 179.0          1
# 187.0          1
# 194.0          1
# 195.0          1
# 508.0          1
# Name: item_cnt_day, Length: 198, dtype: int64

# %%
correlation_train = train_final.corr()

# %%
sns.heatmap(correlation_train, xticklabels=correlation_train.columns, yticklabels=correlation_train.columns, annot=True)

# %%
correlation_test = test_final.corr()

# %%
df = train_final.filter([ "date_block_num" ,"shop_id","item_id","item_price","item_cnt_day","item_category_id"])
df.head()
# Out:
#    date_block_num  shop_id  item_id  item_price  item_cnt_day  \
# 0               0       59    22154       999.0           1.0
# 1               0       25    22154       999.0           1.0
# 2               0       25    22154       999.0           1.0
# 3               0       25    22154       999.0           1.0
# 4               0       25    22154       999.0           1.0
#
#    item_category_id
# 0                37
# 1                37
# 2                37
# 3                37
# 4                37

# %%
l = df.columns.values
number_of_columns=6
number_of_rows = len(l)-1/number_of_columns
plt.figure(figsize=(number_of_columns,5*number_of_rows))
for i in range(0,len(l)):
    plt.subplot(number_of_rows + 1,number_of_columns,i+1)
    sns.set_style('whitegrid')
    sns.boxplot(df[l[i]],color='green',orient='v')
    plt.tight_layout()

# %%
sns.boxplot(x=train_final['item_cnt_day'])

# %%
train_final['item_cnt_day'].describe()
# Out:
# count    2.935849e+06
# mean     1.242641e+00
# std      2.618834e+00
# min     -2.200000e+01
# 25%      1.000000e+00
# 50%      1.000000e+00
# 75%      1.000000e+00
# max      2.169000e+03
# Name: item_cnt_day, dtype: float64

# %%
train_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2935849 entries, 0 to 2935848
# Data columns (total 10 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   date                object
#  1   date_block_num      int64
#  2   shop_id             int64
#  3   item_id             int64
#  4   item_price          float64
#  5   item_cnt_day        float64
#  6   shop_name           object
#  7   item_category_name  object
#  8   item_category_id    int64
#  9   item_name           object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 246.4+ MB

# %%
Q1 = train_final.quantile(0.25)
Q3 = train_final.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# date_block_num         16.0
# shop_id                25.0
# item_id             11208.0
# item_price            750.0
# item_cnt_day            0.0
# item_category_id       27.0
# dtype: float64

# %%
print(train_final < (Q1 - 1.5 * IQR)) |(train_final > (Q3 + 1.5 * IQR))
# Out:
#           date  date_block_num  item_category_id  item_category_name  \
# 0        False           False             False               False
# 1        False           False             False               False
# 2        False           False             False               False
# 3        False           False             False               False
# 4        False           False             False               False
# ...        ...             ...               ...                 ...
# 2935844  False           False             False               False
# 2935845  False           False             False               False
# 2935846  False           False             False               False
# 2935847  False           False             False               False
# 2935848  False           False             False               False
#
#          item_cnt_day  item_id  item_name  item_price  shop_id  shop_name
# ...

# %%
train_final = train_final[~((train_final < (Q1 - 1.5 * IQR)) |(train_final > (Q3 + 1.5 * IQR))).any(axis=1)]
train_final.shape
# Out:
# (2412619, 10)

# %%
train_final.to_csv(r'C:\Users\ASUS\.cookiecutters\cookiecutter-data-science\Sales_Prediction\data\interim\train_final.csv')

# %%
splot = sns.scatterplot(x=train_final['item_cnt_day'], y=train_final['item_price'])

# %%
splot = sns.scatterplot(x=train_final['shop_id'], y=train_final['item_cnt_day'])

# %%
plt.figure(figsize=(12*number_of_columns,10*number_of_rows))
for i in range(0,len(l)):
    plt.subplot(number_of_rows + 1,number_of_columns,i+1)
    sns.distplot(df[l[i]], kde_kws={'bw':0.1})

# %%
sns.distplot(df['item_cnt_day'], kde_kws={'bw':0.1})

# %%
ax = sns.distplot(df['item_cnt_day'], kde_kws={'bw':0.1})
ax.set_yscale('log')

# %%
ax1 = sns.distplot(df['item_price'], kde_kws={'bw':0.1})
ax1.set_yscale('log')

# %%
print('Features Preparation')
# Out:
# Features Preparation

# %%
train_final.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day  \
# 0  02.01.2013               0       59    22154       999.0           1.0
# 1  02.01.2013               0       25    22154       999.0           1.0
# 2  03.01.2013               0       25    22154       999.0           1.0
# 3  20.01.2013               0       25    22154       999.0           1.0
# 4  23.01.2013               0       25    22154       999.0           1.0
#
#                 shop_name item_category_name  item_category_id  \
# 0  Ярославль ТЦ "Альтаир"     Кино - Blu-Ray                37
# 1     Москва ТРК "Атриум"     Кино - Blu-Ray                37
# 2     Москва ТРК "Атриум"     Кино - Blu-Ray                37
# 3     Москва ТРК "Атриум"     Кино - Blu-Ray                37
# 4     Москва ТРК "Атриум"     Кино - Blu-Ray                37
#
#            item_name
# 0  ЯВЛЕНИЕ 2012 (BD)
# 1  ЯВЛЕНИЕ 2012 (BD)
# 2  ЯВЛЕНИЕ 2012 (BD)
# 3  ЯВЛЕНИЕ 2012 (BD)
# 4  ЯВЛЕНИЕ 2012 (BD)
